# %% [markdown]
# # INF8775 – Analyse et conception d’algorithmes
# # TP3 – Automne 2025

# %% [markdown]
# NOM, Prénom, 1234567
#
# NOM, Prénom, 1234567

# %% [markdown]
# Note finale:

# %% [markdown]
# <u>**Date limite de remise :**</u>  6 décembre pour tous

# %% [markdown]
# # Instructions

# %% [markdown]
# ## Rédaction et remise du rapport
#
# - Ce notebook constitue à la fois le sujet du TP, votre code et votre rapport. Il contient déjà du code pour faciliter vos mesures et l'affichage de vos résultats, ainsi qu'un squelette pour votre rapport.
#
# - Complétez directement le notebook, vous êtes libres de créer des nouvelles cellules de code ou de texte.
#
# - Vous pouvez utiliser des fichiers externes pour stocker des exemplaires et des résultats, mais nous devons être capable de comprendre facilement votre démarche et de la reproduire.
#
# - <u>**IMPORTANT**</u> Remettez le fichier du notebook sur Moodle avec le nom `MATRICULE1_MATRICULE2.ipynb`
#
# - Vous pouvez inclure du code trouvé sur Internet, mais vous devez en mentionner la source, sous peine d'être sanctionnés pour plagiat.

# %% [markdown]
# ## Mise en situation
#
# Ce travail pratique se répartit sur deux séances de laboratoire et est une occasion de mettre en application les connaissances vues en cours. Vous devrez développer l'algorithme de votre choix pour essayer de résoudre le plus efficacement possible le problème donné. Une partie de la note sera accordée en fonction des résultats que vous obtiendrez par rapport aux autres équipes.

# %% [markdown]
# ## Description du problème
#
# Dans le cadre de ce TP, nous vous demandons de répondre à un problème combinatoire inspiré du puzzle [Selective Sponges](https://cacm.acm.org/opinion/upstart-puzzles-selective-sponges/) de Dennis E. Shasha (Communications of the ACM).
# Le but est de construire un carré rempli de symboles de manière à satisfaire certaines contraintes sur les séquences qu’il contient.
#
# On considère un carré de taille n × n à remplir à l’aide d’un vocabulaire de k symboles.
# Certaines séquences de symboles sont bannies, d’autres sont objectives.
# Chaque séquence objective présente dans le carré rapporte 1 point, et chaque séquence bannie enlève 1 point.
#
# Votre objectif : concevoir un algorithme qui construit un carré maximisant le score total,
# défini comme la différence entre le nombre de séquences objectifs et le nombre de séquences bannies présentes.

# %% [markdown]
# ## Jeu de données
#
# Dans ce TP, vous avez accès à beaucoup plus de paramètres que les autres fois. Ceux-ci sont : la taille du carré, la taille du vocabulaire, et le nombre de séquences objectifs et le nombre de séquences bannies. Pour générer de sexemplaires, utilisez la fonction generate_dataset qui prend une liste de tuple qui correspond aux quatre parmètres.
#
# *Faites attentions à considérer différentes combinaisons de valeurs pour chaque paramètres autant pour la compétition que pour vos analyses.*

# %%
import random
import time
import statistics
from typing import List, Tuple, Dict


class SpongeGridProblem:
    """
    Représente une instance du problème.

    - n: dimension du carré n×n à produire
    - alphabet: liste de symboles permis (ex: ["A","B","C","I"])
    - targets: séquences qu'on veut VOIR dans la grille
    - banned: séquences qu'on veut ÉVITER dans la grille
    """
    def __init__(
        self,
        n: int,
        alphabet: List[str],
        targets: List[str],
        banned: List[str]
    ):
        self.n = n
        self.alphabet = alphabet
        self.targets = targets
        self.banned = banned


def random_word(alphabet: List[str], length: int) -> str:
    return "".join(random.choice(alphabet) for _ in range(length))


def generate_grid_instance(
    n: int,
    nb_targets: int,
    nb_banned: int,
    alphabet_size: int,
    min_len: int = 2,
    max_len: int = None,
    seed: int = None
) -> SpongeGridProblem:
    """
    Génére une instance avec:
    - un alphabet de taille 'taille_vocabulaire'
    - nb_targets séquences objectifs
    - nb_bannies séquences bannies
    Les longueurs des séquences sont entre min_len et max_len (par défaut max_len = n).
    """
    if seed is not None:
        random.seed(seed)

    if max_len is None:
        max_len = n

    # on construit un alphabet simple comme ['A','B','C','D', ...]
    base_letters = [chr(ord('A') + i) for i in range(alphabet_size)]
    alphabet = base_letters

    targets = [
        random_word(alphabet, random.randint(min_len, max_len))
        for _ in range(nb_targets)
    ]
    banned = [
        random_word(alphabet, random.randint(min_len, max_len))
        for _ in range(nb_banned)
    ]

    return SpongeGridProblem(
        n=n,
        alphabet=alphabet,
        targets=targets,
        banned=banned
    )


def sequences_in_line(line: str, seq: str) -> bool:
    """True si 'seq' apparaît comme sous-chaîne contiguë dans 'line'."""
    return seq in line


def count_matches_in_grid(grid: List[List[str]], seqs: List[str]) -> int:
    """
    Combien de séquences DISTINCTES dans `seqs` apparaissent au moins une fois
    dans le carré (en ligne gauche->droite ou en colonne haut->bas) ?
    """
    n = len(grid)
    # Prépare toutes les lignes (strings)
    rows = ["".join(grid[i][j] for j in range(n)) for i in range(n)]
    cols = ["".join(grid[i][j] for i in range(n)) for j in range(n)]

    found = 0
    for s in seqs:
        present = any(sequences_in_line(r, s) for r in rows) \
                  or any(sequences_in_line(c, s) for c in cols)
        if present:
            found += 1
    return found


def score_grid(
    grid: List[List[str]],
    problem: SpongeGridProblem,
    alpha: float = 1.0,
    beta: float = 1.0
) -> Dict[str, float]:
    """
    Calcule le score = alpha * (#objectifs couverts) - beta * (#bannies déclenchées)
    et renvoie aussi les sous-métriques.
    """
    covered_obj = count_matches_in_grid(grid, problem.targets)
    triggered_bad = count_matches_in_grid(grid, problem.banned)
    score_val = alpha * covered_obj - beta * triggered_bad
    return {
        "score": score_val,
        "covered": covered_obj,
        "triggered": triggered_bad
    }

def generate_samples(
    n: int,
    nb_targets: int,
    nb_banned: int,
    alphabet_size: int,
    num_samples: int = 5,
    seed_base: int = 0
) -> List[SpongeGridProblem]:
    """
    Génère plusieurs instances aléatoires qui partagent les mêmes paramètres
    (n, nb_targets, nb_banned, alphabet_size)
    pour permettre de moyenner la perf de l'algo sur cette famille.
    """
    samples = []
    for k in range(num_samples):
        pb = generate_grid_instance(
            n=n,
            nb_targets=nb_targets,
            nb_banned=nb_banned,
            alphabet_size=alphabet_size,
            seed=seed_base + k
        )
        samples.append(pb)
    return samples


def generate_dataset(
    param_list: List[Tuple[int, int, int, int]],
    num_samples: int = 5,
    seed_base: int = 0
) -> List[SpongeGridProblem]:
    """
    Génère un dataset complet à partir d'une liste de combinaisons de paramètres.

    Args:
        param_list: Liste de tuples (n, nb_targets, nb_banned, alphabet_size).
                   Exemple: [
                       (5, 3, 2, 3),
                       (10, 5, 4, 4),
                       (15, 7, 6, 5)
                   ]
        num_samples: Nombre d'échantillons à générer pour chaque combinaison
        seed_base: Seed pour la génération aléatoire

    Returns:
        dataset : liste de samples
        - samples: liste des SpongeGridProblem générés
    """
    dataset = []

    for i, param_tuple in enumerate(param_list):
        n, nb_targets, nb_banned, alphabet_size = param_tuple


        samples = generate_samples(
            n=n,
            nb_targets=nb_targets,
            nb_banned=nb_banned,
            alphabet_size=alphabet_size,
            num_samples=num_samples,
            seed_base=seed_base + i * num_samples
        )

        dataset.append(samples)

    return dataset

# %%
# Exemple d'utilisation

banned = ["AB", "BA"]
targets = ["AA", "BB"]
alphabet = ["A", "B"]
n = 5

problem = SpongeGridProblem(n=n, alphabet=alphabet, targets=targets, banned=banned)

sample_grid = [
	['A', 'A', 'B', 'A', 'A'],
	['B', 'B', 'A', 'B', 'B'],
	['A', 'A', 'A', 'A', 'A'],
	['B', 'A', 'B', 'A', 'B'],
	['A', 'B', 'A', 'B', 'A']
]

result = score_grid(sample_grid, problem, alpha=1.0, beta=1.0)
print("Score:", result)
# Out:
# Score: {'score': 0.0, 'covered': 2, 'triggered': 2}

# %% [markdown]
# # Implantations et expérimentations

# %% [markdown]
# Ces fonctions auxiliaires vous sont fournies pour vérifier l'exactitude des vos algorithmes, mesurer leurs performance et afficher vos résultats.
#
# Il est recommandé de prendre le temps de lire et comprendre le code.
#
# Exécutez la cellule ci-dessous pour pouvoir utiliser les fonctions auxiliaires.

# %%
import time
from typing import Callable, List, Tuple, Dict
import matplotlib.pyplot as plt
import statistics as stats


class InvalidSolution(Exception):
    def __init__(self, msg="Invalid solution, verify your code."):
        super().__init__(msg)


class Measure:
    """Container for aggregated results over plusieurs échantillons d'une même configuration."""
    def __init__(
        self,
        n: int,
        alphabet_size: int,
        nb_targets: int,
        nb_banned: int,
        mean_time_ms: float,
        mean_score: float,
        mean_targets_covered: float,
        mean_banned_triggered: float,
    ) -> None:
        self.n = n
        self.alphabet_size = alphabet_size
        self.nb_targets = nb_targets
        self.nb_banned = nb_banned
        self.mean_time_ms = mean_time_ms
        self.mean_score = mean_score
        self.mean_targets_covered = mean_targets_covered
        self.mean_banned_triggered = mean_banned_triggered


def is_valid_grid(problem: SpongeGridProblem, grid: List[List[str]]) -> bool:
    """
    Valide la sortie de l'algo:
    - grid doit être une matrice n×n
    - chaque case doit être un symbole autorisé
    """
    # correct shape?
    if len(grid) != problem.n:
        return False
    for row in grid:
        if len(row) != problem.n:
            return False

    # allowed alphabet?
    allowed = set(problem.alphabet)
    for i in range(problem.n):
        for j in range(problem.n):
            if grid[i][j] not in allowed:
                return False

    return True


def measure_single_run(
    procedure: Callable[[SpongeGridProblem], List[List[str]]],
    problem: SpongeGridProblem,
    alpha: float = 1.0,
    beta: float = 1.0,
    time_scale: int = 1000
) -> Tuple[int, Dict[str, float]]:
    """
    Exécute une fois l'algo sur un seul problème.

    Retourne un tuple (elapsed_ms, metrics_dict)
    où metrics_dict contient:
        {
          "score": float,
          "covered": int,
          "triggered": int
        }

    Exceptions:
        InvalidSolution: si la grille retournée est invalide
    """
    start = time.time() * time_scale
    grid = procedure(problem)
    end = time.time() * time_scale

    # structural validation
    if not is_valid_grid(problem, grid):
        raise InvalidSolution("Invalid grid shape or symbols.")

    # compute score
    metrics = score_grid(grid, problem, alpha=alpha, beta=beta)
    
    # metrics = {"score":..., "covered":..., "triggered":...}

    return (round(end - start), metrics)





def measure_mean(
procedure: Callable[[SpongeGridProblem], List[List[str]]],
    problems: List[SpongeGridProblem],
    alpha: float = 1.0,
    beta: float = 1.0,
    time_scale: int = 1000
) -> Measure:
    """
    1. Génère num_samples instances avec les mêmes paramètres.
    2. Lance l'algo sur chacune.
    3. Calcule les moyennes.

    Peut lever InvalidSolution si UNE des exécutions retourne une grille invalide.
    """

    times = []
    scores = []
    covered_list = []
    triggered_list = []
    
    for pb in problems:
        elapsed_ms, metrics = measure_single_run(
            procedure,
            pb,
            alpha=alpha,
            beta=beta,
            time_scale=time_scale
        )
        times.append(elapsed_ms)
        scores.append(metrics["score"])
        covered_list.append(metrics["covered"])
        triggered_list.append(metrics["triggered"])

    mean_time_ms = sum(times) / len(times)
    mean_score = sum(scores) / len(scores)
    mean_cov = sum(covered_list) / len(covered_list)
    mean_trig = sum(triggered_list) / len(triggered_list)
    print('NB problème: ', len(problems))
    print(mean_score)
    return Measure(
        n=problems[0].n,
        alphabet_size=len(problems[0].alphabet),
        nb_targets=len(problems[0].targets),
        nb_banned=len(problems[0].banned),
        mean_time_ms=mean_time_ms,
        mean_score=mean_score,
        mean_targets_covered=mean_cov,
        mean_banned_triggered=mean_trig,
    )


def measure_range(
    procedure: Callable[[SpongeGridProblem], List[List[str]]],
    problems_dataset : List[List[SpongeGridProblem]],
    alpha: float = 1.0,
    beta: float = 1.0,
    time_scale: int = 1000
) -> List[Measure]:
    """
    Applique measure_mean_for_spec() pour chaque config dans specs.
    Retourne une liste de Measure.
    """
    measures: List[Measure] = []
    for problems in problems_dataset:
        m = measure_mean(
            procedure=procedure,
            problems=problems,
            alpha=alpha,
            beta=beta,
            time_scale=time_scale
        )
        measures.append(m)
    return measures


def display_data_as_table(measures: List[Measure]):
    """Affiche un tableau récapitulatif des moyennes mesurées."""
    header = "{: <20} {: <20} {: <20} {: <20} {: <20} {: <20} {: <20} {: <20}"
    row    = "{: <20} {: <20} {: <20} {: <20} {: <20} {: <20} {: <20} {: <20}"

    print(
        header.format(
            "Taille du carré",
            "Taille de l'alphabet",
            "Nombre d'objectifs",
            "Nombre de bannis",
            "Temps(ms)",
            "Score",
            "Objectifs atteints",
            "Pénalités accrus"
        )
    )
    for m in measures:
        print(
            row.format(
                m.n,
                m.alphabet_size,
                m.nb_targets,
                m.nb_banned,
                m.mean_time_ms,
                m.mean_score,
                m.mean_targets_covered,
                m.mean_banned_triggered
            )
        )


### The different tests are below, the names are in french to avoid confusion

def display_test_puissance(vals, title="Test de puissance"):
    x = list(vals.keys())
    y = list(vals.values())

    # Perform linear regression
    m, b = stats.linear_regression(x, y)

    r = list(map(lambda x : m*x + b, x))

    # Create the line equation
    line_eq = f"y = {m:.2f}x + {b:.2f}"

    # Plot the points
    plt.scatter(x, y, label='Mesures')

    # Plot the regression line
    plt.plot(x, r, color="red", label='Regression linéaire')

    # Add labels and title
    plt.xlabel('log Taille')
    plt.ylabel('log Temps')
    plt.title(title)

    # Add legend
    plt.legend(bbox_to_anchor=(0.60, 0), loc='lower left')

    # Display the line equation
    plt.text(min(x), max(y), line_eq)

    # Show the plot
    plt.show()

def display_test_rapport(vals, title="Test du rapport"):
    x = list(vals.keys())
    y = list(vals.values())

    plt.plot(x, y, label='Mesures')
    plt.scatter(x, y, label='Mesures')

    # Add labels and title
    plt.xlabel('Taille')
    plt.ylabel('Temps / f(taille)')
    plt.title(title)
    plt.show()


def display_test_constantes(vals, title="Test des constantes"):
    x = list(vals.keys())
    y = list(vals.values())

    # Perform linear regression
    m, b = stats.linear_regression(x, y)

    r = list(map(lambda x : m*x + b, x))

    # Create the line equation
    line_eq = f"y = {m:.2E}x + {b:.2E}"

    # Plot the points
    plt.scatter(x, y, label='Mesures')

    # Plot the regression line
    plt.plot(x, r, color="red", label='Regression linéaire')

    # Add labels and title
    plt.xlabel('f(Taille)')
    plt.ylabel('Temps')
    plt.title(title)

    # Add legend
    plt.legend(bbox_to_anchor=(0.60, 0), loc='lower left')


    # Display the line equation
    plt.text(min(x), max(y), line_eq)

    # Show the plot
    plt.show()

# %% [markdown]
# # Algorithme (5 pts)

# %% [markdown]
# Votre algorithme sera en partie noté en fonction d'une évaluation relative entre les équipes. 4 points seront donnés aux équipes qui se classeront dans le premier quartile lors de notre évaluation sur un ensemble d'exemplaires. Les équipes se trouvant dans le quartile dont les algorithmes ont le moins bien performé recevront 1 point.
#
# **IMPORTANT** Votre algo doit retourner une solution après 3 minutes. Si ce n'est pas le cas, vous serez pénalisé.

# %%
def get_correct_targets(targets: List[str], banned: List[str]) -> List[str]:
	"""Returns the targets list that are not in the banned list and does not contain any substring that is banned."""
	corrected = []
	banned_set = set(banned)

	for target in targets:
		if target in banned_set:
			continue
		
		is_valid = True
		for banned_sequence in banned:
			if banned_sequence in target:
				is_valid = False
				break
		if is_valid:
			corrected.append(target)

	return corrected
	

eg_banned = ["AB", "BA", "LU"]
eg_targets = ["AA", "BB", "AB", "AAB", "BAA", "SALUT", "LU"]
corrected_targets = get_correct_targets(eg_targets, eg_banned)
print("Corrected Targets:", corrected_targets)


def algo(problem: SpongeGridProblem) -> List[List[str]]:
	banned_set = set(problem.banned)
	target_not_in_banned = [t for t in problem.targets if t not in banned_set]
	n = problem.n
	solution = [[random.choice(problem.alphabet) for _ in range(n)] for _ in range(n)]
	return solution
# Out:
# Corrected Targets: ['AA', 'BB']

# %%
def algo_random(problem: SpongeGridProblem, max_timeout: int = 5):
	start = time.time()
	best_solution = [[random.choice(problem.alphabet) for _ in range(problem.n)] for _ in range(problem.n)]
	best_score = score_grid(best_solution, problem)['score']
	# print(best_score)
	while True:
		if start + max_timeout < time.time():
			break
		solution = [[random.choice(problem.alphabet) for _ in range(problem.n)] for _ in range(problem.n)]
		score = score_grid(solution, problem)['score']
		if best_score < score:
			best_score = score
			best_solution = solution
			# print(best_score)
	
	return best_solution

# %%
EXAMPLE_BANNED = ["AB", "BA"]
EXAMPLE_TARGETS = ["AA", "BB", "AB", "AAB", "BAA"]
EXAMPLE_ALPHABET = ["A", "B"]

EXAMPLE_ROW_1 = ['A', 'B', 'A', 'A', 'B']
EXAMPLE_ROW_2 = ['B', 'A', 'B', 'B', 'A']


def get_dummy_sponge_grid_problem(n: int, tries: int) -> List[SpongeGridProblem]:
	return generate_samples(n=n, nb_targets=25, nb_banned=35, alphabet_size=26, num_samples=tries)

def get_safe_choice(alphabet: List[str], banned: List[str], row: List[str], index: int) -> List[str]:
	"""Returns a list of safe choices from the alphabet that do not create banned sequences when placed at the given index in the row."""
	safe_choices = []
	for character in alphabet:
		row[index] = character
		row_str = "".join(row)
		is_safe = True
		for ban in banned:
			if ban in row_str:
				is_safe = False
				break
		if is_safe:
			safe_choices.append(character)
	return safe_choices

def dummy_get_score_for(row: List[str], targets: List[str], banned: List[str]) -> int:
	"""Dummy function to compute a score for a row based on targets and banned sequences."""
	score = 0
	row_str = "".join(row)
	for target in targets:
		if target in row_str:
			score += 1
	for ban in banned:
		if ban in row_str:
			score -= 1
	return score

def create_optimized_row(
    targets: List[str],
    banned: List[str],
    alphabet: List[str],
    length: int
) -> List[str]:

    def is_safe_row(row: List[str]) -> bool:
        s = "".join(row)
        return all(b not in s for b in banned)

    # 1. Base row (random)
    row = [random.choice(alphabet) for _ in range(length)]

    # 2. Try to insert each target cleanly
    for target in targets:
        L = len(target)
        inserted = False
        
        for start in range(length - L + 1):
            candidate = row.copy()
            candidate[start:start+L] = list(target)

            if is_safe_row(candidate):
                row = candidate
                inserted = True
                break

        # Si pas inséré → on passe, mais sans print ni warning.

    # 3. Local optimization phase (your original scoring logic)
    for i in range(length):
        safe_choices = get_safe_choice(alphabet, banned, row, i)
        if not safe_choices:
            continue

        best_choice = row[i]
        best_score = float('-inf')

        for choice in safe_choices:
            row[i] = choice
            score = dummy_get_score_for(row, targets, banned)

            if score > best_score:
                best_score = score
                best_choice = choice

        row[i] = best_choice

    return row

def optimize_existing_row(
	row: List[str],
	targets: List[str],
	banned: List[str],
	alphabet: List[str],
	max_iterations: int = 1000
	) -> List[str]:
	length = len(row)

	def is_safe_row(r: List[str]) -> bool:
		s = "".join(r)
		return all(b not in s for b in banned)

	for _ in range(max_iterations):
		improved = False

		for i in range(length):
			safe_choices = get_safe_choice(alphabet, banned, row, i)
			if not safe_choices:
				continue

			best_choice = row[i]
			best_score = dummy_get_score_for(row, targets, banned)

			for choice in safe_choices:
				row[i] = choice
				score = dummy_get_score_for(row, targets, banned)

				if score > best_score:
					best_score = score
					best_choice = choice
					improved = True

			row[i] = best_choice

		if not improved:
			break

	return row


def algo_col_row_optimize(problem: SpongeGridProblem, max_timeout: int = 30):
	size = problem.n
	cleaned_banned = get_correct_targets(problem.targets, problem.banned)
	# create n rows
	rows = [create_optimized_row(problem.targets, cleaned_banned, problem.alphabet, size) for _ in range(size)]
	# Look for banned in rows, if some or found swap some of the rows implied in that
	cols = ["".join(rows[i][j] for i in range(size)) for j in range(size)]
	for col in cols:
		for ban in problem.banned:
			if ban in col:
				# find rows involved in the banned sequence
				indices = []
				for start in range(size - len(ban) + 1):
					if col[start:start+len(ban)] == ban:
						indices.extend(range(start, start + len(ban)))
				# swap rows to try to eliminate the banned sequence
				for i in range(len(indices)-1):
					rows[indices[i]], rows[indices[i+1]] = rows[indices[i+1]], rows[indices[i]]
				# update columns after swap
				cols = ["".join(rows[i][j] for i in range(size)) for j in range(size)]
	return rows
from tqdm import tqdm
def dummy_random_grid(problem: SpongeGridProblem, runs: int = 400) -> List[List[str]]:
	size = problem.n
	# generate a grid and then another, if better score keep it, do this 50 times
	best_grid = [[random.choice(problem.alphabet) for _ in range(size)] for _ in range(size)]
	best_score = score_grid(best_grid, problem)['score']
	for _ in tqdm(range(runs)):
		grid = [[random.choice(problem.alphabet) for _ in range(size)] for _ in range(size)]
		score = score_grid(grid, problem)['score']
		if best_score < score:
			best_score = score
			best_grid = grid
	return best_grid

def dummy_combine_algo(problem: SpongeGridProblem) -> List[List[str]]:
	# starts with a grid from random algo and then optimizes each row with create_optimized_row
	start_grid = dummy_random_grid(problem)
	optimized_grid = []
	for row in start_grid:
		optimized_row = create_optimized_row(
			targets=problem.targets,
			banned=problem.banned,
			alphabet=problem.alphabet,
			length=problem.n
		)
		optimized_grid.append(optimized_row)
	return optimized_grid

# %%
from heapq import _heapify_max, _heappop_max

class Sample():
	problem: SpongeGridProblem
	def __init__(self, grid: List[List[str]]):
		self.grid = grid
		self.score = score_grid(grid, Sample.problem)['score']
	def __lt__(self, other):
		return self.score < other.score

# maybe use a heap (but we would need to implement by ourselve)
def selection(population: List[List[List[str]]], nb_parent: int, selection_threshold: int) -> list[list[list[str]]]:
	population_sorted: list[Sample] = [Sample(grid.copy()) for grid in population]
	_heapify_max(population_sorted)
	# print('Best score: ', population_sorted[0].score)
	best_population = []
	for i in range(nb_parent):
		sample = _heappop_max(population_sorted)
		if i == 0:
			print('Score: ', sample.score)
			time.sleep(1)
		if sample.score < selection_threshold:
			break
		#print(sample.score)
		best_population.append(sample.grid)
	return best_population

# We could skip the fixed gene from the past iteration
def crossing(common_parent: list[list[str]], parents: List[List[List[str]]]) -> list[list[str]]:
	# common_grid: list[list[str]] = [[' ' for _ in range(Sample.problem.n)] for _ in range(Sample.problem.n)]
	for i in range(Sample.problem.n):
		for j in range(Sample.problem.n):
			# If we get to an already fixed gene then we can pass over it
			if common_parent[i][j] != ' ':
				continue

			count_char = dict()
			for grid in parents:
				if grid[i][j] in count_char:
					count_char[grid[i][j]] += 1
				else:
					count_char[grid[i][j]] = 1
			for key, value in count_char.items():
				if value > len(parents) / 2:
					common_parent[i][j] = key
					break
	return common_parent
			
def mutation(common_parent: List[List[str]], nb_sample) -> Tuple[list[list[list[str]]], bool]:
	new_population: list[list[list[str]]] = []
	has_mutated = False
	
	for k in range(nb_sample):
		new_population.append([])
		for i in range(Sample.problem.n):
			new_population[k].append([])
			for j in range(Sample.problem.n):
				if common_parent[i][j] != ' ':
					symbol = common_parent[i][j] 
				else:
					symbol = random.choice(Sample.problem.alphabet)
					has_mutated = True
				new_population[k][i].append(symbol)
		if not has_mutated:
			print('NO MORE MUTATION POSSIBLE')
			return ([common_parent], False)
	
	return (new_population, True)

		

# Démarrer avec une certaine population P0
# i <- 0
# tant que critère d'arrêt
#   P_parents <- sélection(P0, nb_parent, compare_func)
#   P_commun  <- croisement(P_parents)
#   P_mutées  <- mutation(P_commun)
#   Pi        <- P_mutées
# retourner sélection(Pi, 1, f)



def algo_random_evolution(problem: SpongeGridProblem, max_timeout: int = 180):
	end = time.time() + max_timeout
	has_mutated = True

	Sample.problem = problem
	nb_sample = (problem.n ** 2) // 3
	nb_selected = nb_sample // 3
	population = [[[random.choice(problem.alphabet) for _ in range(problem.n)] for _ in range(problem.n)] for _ in range(nb_sample)]
	common_parent: list[list[str]] = [[' ' for _ in range(Sample.problem.n)] for _ in range(Sample.problem.n)]
	
	selection_threshold = 0
	nb_generation_without_improvement = 0
	LIMIT_GENERATION_WITHOUT_IMPROVEMENT = 100
	generation = 0
	# MAX_GENERATION_WITHOUT_EVOLUTION = 1000
	while end > time.time() and has_mutated:
		generation += 1
		#print('Generation: ', generation)
		old_threshold = selection_threshold
		pass_selection = False
		test = 0
		while not pass_selection and end > time.time():
			print(f'Génération: {generation} | itération: {test}')
			parents_selected = selection(population, nb_selected, selection_threshold)
			if len(parents_selected) >= nb_selected / 2:
				pass_selection = True
			else:
				population, _ = mutation(common_parent, nb_sample)
			test += 1

		if end < time.time():
			break

		selection_threshold = score_grid(parents_selected[len(parents_selected) // 2], problem)['score']
		if selection_threshold == old_threshold:
			nb_generation_without_improvement += 1
			if nb_generation_without_improvement == LIMIT_GENERATION_WITHOUT_IMPROVEMENT:
				break
		
		if generation % 100 == 0:
			print(f'Meilleur score de la génération {generation}: {score_grid(parents_selected[0], problem)['score']}')
		population, has_mutated = mutation(crossing(common_parent, parents_selected), nb_sample)

		
	return parents_selected[0]

# %%
import math
# En partie insipiré par https://www.geeksforgeeks.org/dsa/implement-simulated-annealing-in-python/
# et https://fr.wikipedia.org/wiki/Recuit_simul%C3%A9

## Définition des variables

# Soit n la taille du carré (e.g. n=4 veut dire un carré de 4 x 4)

# Soit a la taille de l'alphabet

# Soit o le nombre d'objectifs

# Soit b le nombre de bannis 

def generate_weighted_grid(problem: SpongeGridProblem) -> List[List[str]]:
    """
    Generates an initial grid where characters are chosen based on their frequency in the target sequences.
    Total raw complexity: O(a + (o * l) + (a + o * l) + n^2)
    """
    counts = {char: 0 for char in problem.alphabet} # O(a) (voir définition des variables plus bas)
    total = 0

    for target in problem.targets: # O(o * l)
        for char in target: # O(l)
            counts[char] += 1
            total += 1

    weighted_chars = []

    for char, count in counts.items(): # O(a + o * l)
        weighted_chars.extend([char] * (count + 1))

    return [[random.choice(weighted_chars) for _ in range(problem.n)] for _ in range(problem.n)] # O(n^2)


def simulated_annealing_algo(problem: SpongeGridProblem, temperature: float = 15.0, cooling_rate: float = 0.9999, max_time_seconds: int = 180) -> List[List[str]]:
    """
    Simulated annealing algorithm to optimize the grid configuration for the given problem.
    Args:
        problem: An instance of SpongeGridProblem.
        temperature: Initial temperature for the annealing process.
        cooling_rate: Rate at which the temperature decreases.
        max_time_seconds: Maximum time to run the algorithm.
    Returns:
        A 2D list representing the optimized grid the algorithm was able to find.
    """
    start_time = time.time()
    
    MIN_TEMPERATURE = 0.001
    MAX_STAGNATION = 10_000
    
    current_grid = generate_weighted_grid(problem)
    
    current_score = score_grid(current_grid, problem)['score']
    
    best_grid = [row[:] for row in current_grid]
    best_score = current_score
    
    iteration = 0
    nb_iterations_without_improvement = 0
    
    while (time.time() - start_time) < max_time_seconds:
        
        if temperature < MIN_TEMPERATURE:
            break

        if nb_iterations_without_improvement > MAX_STAGNATION:
            break

        random_x, random_y = random.randint(0, problem.n - 1), random.randint(0, problem.n - 1)
        old_character = current_grid[random_x][random_y]
        new_character = random.choice(problem.alphabet)
        
        if new_character == old_character:
            continue 
            
        current_grid[random_x][random_y] = new_character
        
        new_score = score_grid(current_grid, problem)['score']
        
        delta = new_score - current_score
        
        accept = False
        
        if delta > 0:
            accept = True
        else:
            try:
                probability = math.exp(delta / temperature)
            except OverflowError:
                probability = 0
            if random.random() < probability:
                accept = True
        
        if accept:
            current_score = new_score
            
            if current_score > best_score:
                best_score = current_score
                best_grid = [row[:] for row in current_grid]
                nb_iterations_without_improvement = 0
            else:
                nb_iterations_without_improvement += 1
        else:
            current_grid[random_x][random_y] = old_character
            nb_iterations_without_improvement += 1
        
        if iteration % 100 == 0:
            temperature *= cooling_rate
            
        iteration += 1
            
    return best_grid

# %%
specs = [
    (4, 6, 6, 4),
    (6, 10, 8, 4),
    (8, 15, 15, 5),
    (10, 20, 20, 5),
    (12, 25, 25, 6),
    (14, 30, 30, 6),
    (16, 35, 35, 10),
    (15, 35, 35, 10),
    (18, 40, 40, 15),
    (20, 45, 45, 20),
    (25, 55, 55, 25),
    (40, 75, 75, 25),
    (100, 150, 150, 30),
]

dataset=generate_dataset(specs, 3, 2)

# %%
results = measure_range(
    procedure=algo_random_evolution,
    problems_dataset=dataset,
)

results2 = measure_range(
    procedure=simulated_annealing_algo,
    problems_dataset=dataset,
)
# Out:
# Génération: 1 | itération: 0
# Score:  0.0
# NO MORE MUTATION POSSIBLE
# Génération: 1 | itération: 0
# Score:  0.0
# NO MORE MUTATION POSSIBLE
# Génération: 1 | itération: 0
# Score:  2.0
# NO MORE MUTATION POSSIBLE
# NB problème:  3
# 0.6666666666666666
# Génération: 1 | itération: 0
# Score:  4.0
# Génération: 2 | itération: 0
# Score:  3.0
# Génération: 2 | itération: 1
# Score:  5.0
# Génération: 3 | itération: 0
# Score:  5.0
# Génération: 4 | itération: 0
# Score:  6.0
# Génération: 5 | itération: 0
# Score:  6.0
# Génération: 6 | itération: 0
# Score:  7.0
# Génération: 7 | itération: 0
# Score:  7.0
# Génération: 8 | itération: 0
# Score:  7.0
# Génération: 9 | itération: 0
# Score:  7.0
# Génération: 10 | itération: 0
# Score:  7.0
# Génération: 11 | itération: 0
# Score:  7.0
# Génération: 12 | itération: 0
# Score:  7.0
# Génération: 13 | itération: 0
# Score:  7.0
# Génération: 14 | itération: 0
# Score:  7.0
# Génération: 15 | itération: 0
# Score:  7.0
# Génération: 16 | itération: 0
# Score:  7.0
# NO MORE MUTATION POSSIBLE
# Génération: 1 | itération: 0
# Score:  3.0
# Génération: 2 | itération: 0
# Score:  2.0
# Génération: 3 | itération: 0
# Score:  3.0
# Génération: 4 | itération: 0
# Score:  3.0
# Génération: 5 | itération: 0
# Score:  3.0
# Génération: 6 | itération: 0
# Score:  3.0
# Génération: 7 | itération: 0
# Score:  3.0
# Génération: 8 | itération: 0
# Score:  3.0
# Génération: 9 | itération: 0
# Score:  3.0
# Génération: 10 | itération: 0
# Score:  3.0
# Génération: 11 | itération: 0
# Score:  3.0
# Génération: 12 | itération: 0
# Score:  3.0
# Génération: 13 | itération: 0
# Score:  3.0
# Génération: 14 | itération: 0
# Score:  3.0
# Génération: 15 | itération: 0
# Score:  3.0
# Génération: 16 | itération: 0
# Score:  3.0
# Génération: 17 | itération: 0
# Score:  3.0
# Génération: 18 | itération: 0
# Score:  3.0
# Génération: 19 | itération: 0
# Score:  3.0
# Génération: 20 | itération: 0
# Score:  3.0
# Génération: 21 | itération: 0
# Score:  3.0
# Génération: 22 | itération: 0
# Score:  3.0
# NO MORE MUTATION POSSIBLE
# Génération: 1 | itération: 0
# Score:  0.0
# Génération: 1 | itération: 1
# Score:  1.0
# Génération: 2 | itération: 0
# Score:  0.0
# Génération: 3 | itération: 0
# Score:  0.0
# Génération: 3 | itération: 1
# Score:  -1.0
# Génération: 3 | itération: 2
# Score:  1.0
# Génération: 4 | itération: 0
# Score:  0.0
# Génération: 5 | itération: 0
# Score:  0.0
# Génération: 6 | itération: 0
# Score:  0.0
# Génération: 7 | itération: 0
# Score:  0.0
# Génération: 8 | itération: 0
# Score:  0.0
# NO MORE MUTATION POSSIBLE
# NB problème:  3
# 3.3333333333333335
# Génération: 1 | itération: 0
# Score:  5.0
# Génération: 2 | itération: 0
# Score:  4.0
# Génération: 3 | itération: 0
# Score:  4.0
# Génération: 4 | itération: 0
# Score:  5.0
# Génération: 5 | itération: 0
# Score:  4.0
# Génération: 5 | itération: 1
# Score:  4.0
# Génération: 5 | itération: 2
# Score:  6.0
# Génération: 6 | itération: 0
# Score:  5.0
# Génération: 7 | itération: 0
# Score:  6.0
# Génération: 8 | itération: 0
# Score:  6.0
# Génération: 9 | itération: 0
# Score:  6.0
# Génération: 9 | itération: 1
# Score:  6.0
# Génération: 10 | itération: 0
# Score:  6.0
# Génération: 11 | itération: 0
# Score:  6.0
# Génération: 12 | itération: 0
# Score:  6.0
# Génération: 13 | itération: 0
# Score:  6.0
# Génération: 14 | itération: 0
# Score:  6.0
# Génération: 15 | itération: 0
# Score:  6.0
# Génération: 16 | itération: 0
# Score:  6.0
# Génération: 17 | itération: 0
# Score:  6.0
# Génération: 18 | itération: 0
# Score:  6.0
# Génération: 19 | itération: 0
# Score:  6.0
# Génération: 20 | itération: 0
# Score:  6.0
# NO MORE MUTATION POSSIBLE
# Génération: 1 | itération: 0
# Score:  2.0
# Génération: 2 | itération: 0
# Score:  3.0
# Génération: 3 | itération: 0
# Score:  4.0
# Génération: 4 | itération: 0
# Score:  3.0
# Génération: 5 | itération: 0
# Score:  3.0
# Génération: 6 | itération: 0
# Score:  3.0
# Génération: 6 | itération: 1
# Score:  3.0
# Génération: 7 | itération: 0
# Score:  3.0
# Génération: 8 | itération: 0
# Score:  3.0
# Génération: 9 | itération: 0
# Score:  3.0
# Génération: 10 | itération: 0
# Score:  3.0
# Génération: 10 | itération: 1
# Score:  3.0
# Génération: 11 | itération: 0
# Score:  3.0
# Génération: 12 | itération: 0
# Score:  3.0
# Génération: 13 | itération: 0
# Score:  3.0
# Génération: 14 | itération: 0
# Score:  3.0
# Génération: 15 | itération: 0
# Score:  3.0
# Génération: 16 | itération: 0
# Score:  3.0
# Génération: 17 | itération: 0
# Score:  3.0
# Génération: 18 | itération: 0
# Score:  3.0
# Génération: 19 | itération: 0
# Score:  3.0
# Génération: 20 | itération: 0
# Score:  3.0
# Génération: 21 | itération: 0
# Score:  3.0
# Génération: 22 | itération: 0
# Score:  3.0
# Génération: 23 | itération: 0
# Score:  3.0
# NO MORE MUTATION POSSIBLE
# Génération: 1 | itération: 0
# Score:  3.0
# Génération: 2 | itération: 0
# Score:  3.0
# Génération: 3 | itération: 0
# Score:  2.0
# Génération: 4 | itération: 0
# Score:  2.0
# Génération: 5 | itération: 0
# Score:  3.0
# Génération: 6 | itération: 0
# Score:  3.0
# Génération: 7 | itération: 0
# Score:  3.0
# Génération: 8 | itération: 0
# Score:  2.0
# Génération: 9 | itération: 0
# Score:  2.0
# Génération: 9 | itération: 1
# Score:  3.0
# Génération: 9 | itération: 2
# Score:  3.0
# Génération: 10 | itération: 0
# Score:  3.0
# Génération: 11 | itération: 0
# Score:  2.0
# Génération: 12 | itération: 0
# Score:  3.0
# Génération: 13 | itération: 0
# Score:  3.0
# Génération: 14 | itération: 0
# Score:  3.0
# Génération: 15 | itération: 0
# Score:  3.0
# Génération: 15 | itération: 1
# Score:  3.0
# Génération: 15 | itération: 2
# Score:  3.0
# Génération: 16 | itération: 0
# Score:  3.0
# Génération: 17 | itération: 0
# Score:  3.0
# Génération: 18 | itération: 0
# Score:  4.0
# Génération: 19 | itération: 0
# Score:  4.0
# Génération: 20 | itération: 0
# Score:  4.0
# Génération: 21 | itération: 0
# Score:  4.0
# NO MORE MUTATION POSSIBLE
# NB problème:  3
# 4.333333333333333
# Génération: 1 | itération: 0
# Score:  3.0
# Génération: 2 | itération: 0
# Score:  4.0
# Génération: 3 | itération: 0
# Score:  4.0
# Génération: 4 | itération: 0
# Score:  4.0
# Génération: 5 | itération: 0
# Score:  3.0
# Génération: 5 | itération: 1
# Score:  3.0
# Génération: 6 | itération: 0
# Score:  5.0
# Génération: 7 | itération: 0
# Score:  4.0
# Génération: 7 | itération: 1
# Score:  5.0
# Génération: 7 | itération: 2
# Score:  4.0
# Génération: 7 | itération: 3
# Score:  4.0
# Génération: 7 | itération: 4
# Score:  4.0
# Génération: 7 | itération: 5
# Score:  4.0
# Génération: 7 | itération: 6
# Score:  5.0
# Génération: 7 | itération: 7
# Score:  4.0
# Génération: 7 | itération: 8
# Score:  4.0
# Génération: 7 | itération: 9
# Score:  4.0
# Génération: 7 | itération: 10
# Score:  4.0
# Génération: 8 | itération: 0
# Score:  4.0
# Génération: 8 | itération: 1
# Score:  5.0
# Génération: 9 | itération: 0
# Score:  5.0
# Génération: 10 | itération: 0
# Score:  5.0
# Génération: 11 | itération: 0
# Score:  5.0
# Génération: 12 | itération: 0
# Score:  5.0
# Génération: 13 | itération: 0
# Score:  5.0
# Génération: 14 | itération: 0
# Score:  6.0
# Génération: 15 | itération: 0
# Score:  7.0
# Génération: 16 | itération: 0
# Score:  6.0
# Génération: 17 | itération: 0
# Score:  7.0
# Génération: 18 | itération: 0
# Score:  7.0
# Génération: 19 | itération: 0
# Score:  6.0
# Génération: 20 | itération: 0
# Score:  6.0
# Génération: 21 | itération: 0
# Score:  7.0
# Génération: 22 | itération: 0
# Score:  7.0
# Génération: 23 | itération: 0
# Score:  7.0
# Génération: 24 | itération: 0
# Score:  6.0
# Génération: 25 | itération: 0
# Score:  6.0
# Génération: 26 | itération: 0
# Score:  6.0
# Génération: 27 | itération: 0
# Score:  6.0
# Génération: 28 | itération: 0
# Score:  6.0
# Génération: 29 | itération: 0
# Score:  6.0
# Génération: 30 | itération: 0
# Score:  6.0
# Génération: 31 | itération: 0
# Score:  6.0
# Génération: 32 | itération: 0
# Score:  6.0
# Génération: 33 | itération: 0
# Score:  6.0
# Génération: 34 | itération: 0
# Score:  6.0
# Génération: 35 | itération: 0
# Score:  6.0
# Génération: 36 | itération: 0
# Score:  6.0
# Génération: 37 | itération: 0
# Score:  6.0
# Génération: 38 | itération: 0
# Score:  6.0
# Génération: 39 | itération: 0
# Score:  6.0
# Génération: 40 | itération: 0
# Score:  6.0
# Génération: 41 | itération: 0
# Score:  6.0
# Génération: 42 | itération: 0
# Score:  6.0
# Génération: 43 | itération: 0
# Score:  6.0
# Génération: 44 | itération: 0
# Score:  6.0
# Génération: 45 | itération: 0
# Score:  6.0
# Génération: 46 | itération: 0
# Score:  6.0
# Génération: 47 | itération: 0
# Score:  6.0
# Génération: 48 | itération: 0
# Score:  6.0
# Génération: 49 | itération: 0
# Score:  6.0
# Génération: 50 | itération: 0
# Score:  6.0
# Génération: 51 | itération: 0
# Score:  6.0
# Génération: 52 | itération: 0
# Score:  6.0
# Génération: 53 | itération: 0
# Score:  6.0
# Génération: 54 | itération: 0
# Score:  6.0
# Génération: 55 | itération: 0
# Score:  6.0
# Génération: 56 | itération: 0
# Score:  6.0
# Génération: 57 | itération: 0
# Score:  6.0
# Génération: 58 | itération: 0
# Score:  6.0
# Génération: 59 | itération: 0
# Score:  6.0
# Génération: 60 | itération: 0
# Score:  6.0
# Génération: 61 | itération: 0
# Score:  6.0
# NO MORE MUTATION POSSIBLE
# Génération: 1 | itération: 0
# Score:  5.0
# Génération: 2 | itération: 0
# Score:  5.0
# Génération: 3 | itération: 0
# Score:  4.0
# Génération: 4 | itération: 0
# Score:  4.0
# Génération: 5 | itération: 0
# Score:  4.0
# Génération: 5 | itération: 1
# Score:  3.0
# Génération: 5 | itération: 2
# Score:  4.0
# Génération: 5 | itération: 3
# Score:  5.0
# Génération: 5 | itération: 4
# Score:  4.0
# Génération: 5 | itération: 5
# Score:  3.0
# Génération: 5 | itération: 6
# Score:  4.0
# Génération: 5 | itération: 7
# Score:  4.0
# Génération: 5 | itération: 8
# Score:  3.0
# Génération: 5 | itération: 9
# Score:  5.0
# Génération: 6 | itération: 0
# Score:  4.0
# Génération: 7 | itération: 0
# Score:  4.0
# Génération: 8 | itération: 0
# Score:  3.0
# Génération: 8 | itération: 1
# Score:  3.0
# Génération: 9 | itération: 0
# Score:  3.0
# Génération: 10 | itération: 0
# Score:  4.0
# Génération: 11 | itération: 0
# Score:  4.0
# Génération: 12 | itération: 0
# Score:  5.0
# Génération: 13 | itération: 0
# Score:  5.0
# Génération: 14 | itération: 0
# Score:  5.0
# Génération: 15 | itération: 0
# Score:  6.0
# Génération: 15 | itération: 1
# Score:  6.0
# Génération: 15 | itération: 2
# Score:  6.0
# Génération: 15 | itération: 3
# Score:  5.0
# Génération: 15 | itération: 4
# Score:  6.0
# Génération: 15 | itération: 5
# Score:  6.0
# Génération: 16 | itération: 0
# Score:  6.0
# Génération: 17 | itération: 0
# Score:  6.0
# Génération: 18 | itération: 0
# Score:  6.0
# Génération: 19 | itération: 0
# Score:  6.0
# Génération: 20 | itération: 0
# Score:  6.0
# Génération: 21 | itération: 0
# Score:  6.0
# Génération: 22 | itération: 0
# Score:  7.0
# Génération: 23 | itération: 0
# Score:  6.0
# Génération: 24 | itération: 0
# Score:  6.0
# Génération: 25 | itération: 0
# Score:  6.0
# Génération: 26 | itération: 0
# Score:  6.0
# Génération: 27 | itération: 0
# Score:  6.0
# Génération: 28 | itération: 0
# Score:  6.0
# Génération: 29 | itération: 0
# Score:  6.0
# Génération: 30 | itération: 0
# Score:  6.0
# Génération: 31 | itération: 0
# Score:  6.0
# Génération: 32 | itération: 0
# Score:  6.0
# Génération: 33 | itération: 0
# Score:  6.0
# Génération: 34 | itération: 0
# Score:  6.0
# Génération: 35 | itération: 0
# Score:  6.0
# Génération: 36 | itération: 0
# Score:  6.0
# Génération: 37 | itération: 0
# Score:  6.0
# Génération: 38 | itération: 0
# Score:  6.0
# Génération: 39 | itération: 0
# Score:  6.0
# Génération: 40 | itération: 0
# Score:  6.0
# Génération: 41 | itération: 0
# Score:  6.0
# Génération: 42 | itération: 0
# Score:  6.0
# Génération: 43 | itération: 0
# Score:  6.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 results = measure_range(
#       2     procedure=algo_random_evolution,
#       3     problems_dataset=dataset,
#       4 )
#       6 results2 = measure_range(
#       7     procedure=simulated_annealing_algo,
#       8     problems_dataset=dataset,
#       9 )
#
# Cell In[4], line 162, in measure_range(procedure, problems_dataset, alpha, beta, time_scale)
#     160 measures: List[Measure] = []
#     161 for problems in problems_dataset:
# --> 162     m = measure_mean(
#     163         procedure=procedure,
#     164         problems=problems,
#     165         alpha=alpha,
#     166         beta=beta,
#     167         time_scale=time_scale
#     168     )
#     169     measures.append(m)
#     170 return measures
#
# Cell In[4], line 119, in measure_mean(procedure, problems, alpha, beta, time_scale)
#     116 triggered_list = []
#     118 for pb in problems:
# --> 119     elapsed_ms, metrics = measure_single_run(
#     120         procedure,
#     121         pb,
#     122         alpha=alpha,
#     123         beta=beta,
#     124         time_scale=time_scale
#     125     )
#     126     times.append(elapsed_ms)
#     127     scores.append(metrics["score"])
#
# Cell In[4], line 80, in measure_single_run(procedure, problem, alpha, beta, time_scale)
#      65 """
#      66 Exécute une fois l'algo sur un seul problème.
#      67
#    (...)     77     InvalidSolution: si la grille retournée est invalide
#      78 """
#      79 start = time.time() * time_scale
# ---> 80 grid = procedure(problem)
#      81 end = time.time() * time_scale
#      83 # structural validation
#
# Cell In[26], line 106, in algo_random_evolution(problem, max_timeout)
#     104 while not pass_selection and end > time.time():
#     105 	print(f'Génération: {generation} | itération: {test}')
# --> 106 	parents_selected = selection(population, nb_selected, selection_threshold)
#     107 	if len(parents_selected) >= nb_selected / 2:
#     108 		pass_selection = True
#
# Cell In[26], line 21, in selection(population, nb_parent, selection_threshold)
#      19 if i == 0:
#      20 	print('Score: ', sample.score)
# ---> 21 	time.sleep(1)
#      22 if sample.score < selection_threshold:
#      23 	break
#
# KeyboardInterrupt:

# %%
print('algo_random_evolution')
display_data_as_table(results)
print('simulated_annealing_algo')
display_data_as_table(results2)

# %% [markdown]
# # Analyse asymptotique (2 pts)
#
# Effectuer une analyse asymptotique de votre algorithme.

# %% [markdown]
# ## Définition des variables
#
# Soit n la taille du carré (e.g. n=4 veut dire un carré de 4 x 4)
#
# Soit a la taille de l'alphabet
#
# Soit o le nombre d'objectifs et l la longueur maximale d'un objectif (pire cas)
#
# Soit b le nombre de bannis
#
# ## Analyse de la fonction `generate_weighted_grid`
#
# Tel que les commentaires dans le code l'expliquent, la complexité totale est dans O(a + (o * l) + (a + o * l) + n^2).
# En développant, nous obtenons O(a + a + 2 * (o * l) + n^2) donc O(2a + 2(o*l) + n^2). Les constantes multiplicatives étant négligées en notation asymptotique, nous obtenons que la complexité est dans O(a + (o * l) + n^2). Aucune des variables mentionnées n'a le potentiel de croître significativement plus rapidement que les autres. En effet, leurs étandues sont tous similaires. Il ne peut donc pas y avoir de simplification supplémentaire.

# %% [markdown]
# # Analyse hybride (6 pts)
#
# Effectuer une analyse hybride de votre algorithme.

# %% [markdown]
# # Analyse code carbon (1 pts)
#
# Effectuer une anlayse code carbon en sélectionnant différent pays pour l'analyse. Commenter vos résultats.

# %% [markdown]
# ## Évolution de votre algorithme et Conclusion (6 pts)
#
# Faites une synthèse de vos analyses pour mettre en évidence les qualités et défauts de votre algorithme. Mentionnez les améliorations qui vous ont permis d'atteindre votre algorithme actuel ainsi que des pistes d'améliorations potentielles restantes.

# %% [markdown]
#  ## Autres critères
#  Qualité du code
#
# Présentation générale
#
# - Concision
# - Qualité du français
#
# Pénalité retard
# - -2 pt / journée de retard, arrondi vers le haut. Les TPs ne sont plus acceptés après 3 jours.
